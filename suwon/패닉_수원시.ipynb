# %%
# -*- coding:utf-8 -*-

import numpy as np
import pandas as pd

# 시각화
import folium
from folium.plugins import HeatMap
import folium.plugins as plugins

from geoband.API import *
import pathlib

# %%
input_path = pathlib.Path('./input')
if not input_path.is_dir():
    input_path.mkdir()
    
GetCompasData('SBJ_2102_002', '1', input_path.joinpath('1.수원시_버스정류장.csv'))
GetCompasData('SBJ_2102_002', '2', input_path.joinpath('2.수원시_버스정류장별_승하차이력(1).csv'))
GetCompasData('SBJ_2102_002', '3', input_path.joinpath('3.수원시_버스정류장별_승하차이력(2).csv'))
GetCompasData('SBJ_2102_002', '4', input_path.joinpath('4.수원시_버스정류장별_승하차이력(3).csv'))
GetCompasData('SBJ_2102_002', '5', input_path.joinpath('5.수원시_버스정류장별_승하차이력(4).csv'))
GetCompasData('SBJ_2102_002', '6', input_path.joinpath('6.수원시_버스정류장별_승하차이력(5).csv'))
GetCompasData('SBJ_2102_002', '7', input_path.joinpath('7.수원시_버스정류장별_노선현황.csv'))
GetCompasData('SBJ_2102_002', '8', input_path.joinpath('8.수원시_지하철역_위치정보.csv'))
GetCompasData('SBJ_2102_002', '9', input_path.joinpath('9.수원시_지하철역별_이용현황(2017~2019).csv'))
GetCompasData('SBJ_2102_002', '10', input_path.joinpath('10.수원시_옥외광고물현황.csv'))
GetCompasData('SBJ_2102_002', '11', input_path.joinpath('11.수원시_대기오염도_측정현황.csv'))
GetCompasData('SBJ_2102_002', '12', input_path.joinpath('12.수원시_주차장현황.csv'))
GetCompasData('SBJ_2102_002', '13', input_path.joinpath('13.수원시_기상데이터(2020).csv'))
GetCompasData('SBJ_2102_002', '14', input_path.joinpath('14.수원시_시간대별_유동인구(2020).csv'))
GetCompasData('SBJ_2102_002', '15', input_path.joinpath('15.수원시_성연령별_유동인구(2020).csv'))
GetCompasData('SBJ_2102_002', '16', input_path.joinpath('16.수원시_요일별_유동인구(2020).csv'))
GetCompasData('SBJ_2102_002', '17', input_path.joinpath('17.수원시_인구정보(고령)_격자.geojson'))
GetCompasData('SBJ_2102_002', '18', input_path.joinpath('18.수원시_인구정보(생산가능)_격자.geojson'))
GetCompasData('SBJ_2102_002', '19', input_path.joinpath('19.수원시_인구정보(유소년)_격자.geojson'))
GetCompasData('SBJ_2102_002', '20', input_path.joinpath('20.수원시_교통노드.geojson'))
GetCompasData('SBJ_2102_002', '21', input_path.joinpath('21.수원시_교통링크.geojson'))
GetCompasData('SBJ_2102_002', '22', input_path.joinpath('22.수원시_상세도로망_LV6.geojson'))
GetCompasData('SBJ_2102_002', '23', input_path.joinpath('23.수원시_평일_일별_시간대별_추정교통량_LV6.csv'))
GetCompasData('SBJ_2102_002', '24', input_path.joinpath('24.수원시_평일_일별_혼잡빈도강도_LV6.csv'))
GetCompasData('SBJ_2102_002', '25', input_path.joinpath('25.수원시_평일_일별_혼잡시간강도_LV6.csv'))
GetCompasData('SBJ_2102_002', '26', input_path.joinpath('26.수원시_인도(2017).geojson'))
GetCompasData('SBJ_2102_002', '27', input_path.joinpath('27.수원시_도로명주소(건물).geojson'))
GetCompasData('SBJ_2102_002', '28', input_path.joinpath('28.수원시_건물연면적_격자.geojson'))
GetCompasData('SBJ_2102_002', '29', input_path.joinpath('29.수원시_법정경계(시군구).geojson'))
GetCompasData('SBJ_2102_002', '30', input_path.joinpath('30.수원시_법정경계(읍면동).geojson'))
GetCompasData('SBJ_2102_002', '31', input_path.joinpath('31.수원시_행정경계(읍면동).geojson'))
GetCompasData('SBJ_2102_002', '32', input_path.joinpath('32.수원시_지적도.geojson'))

for path in list(input_path.glob('*.csv')) + list(input_path.glob('*.geojson')):
    print(path)
# Out:
# input/1.수원시_버스정류장.csv
# input/2.수원시_버스정류장별_승하차이력(1).csv
# input/3.수원시_버스정류장별_승하차이력(2).csv
# input/4.수원시_버스정류장별_승하차이력(3).csv
# input/5.수원시_버스정류장별_승하차이력(4).csv
# input/6.수원시_버스정류장별_승하차이력(5).csv
# input/7.수원시_버스정류장별_노선현황.csv
# input/8.수원시_지하철역_위치정보.csv
# input/9.수원시_지하철역별_이용현황(2017~2019).csv
# input/10.수원시_옥외광고물현황.csv
# input/11.수원시_대기오염도_측정현황.csv
# input/12.수원시_주차장현황.csv
# input/13.수원시_기상데이터(2020).csv
# input/14.수원시_시간대별_유동인구(2020).csv
# input/15.수원시_성연령별_유동인구(2020).csv
# input/16.수원시_요일별_유동인구(2020).csv
# input/23.수원시_평일_일별_시간대별_추정교통량_LV6.csv
# input/24.수원시_평일_일별_혼잡빈도강도_LV6.csv
# input/25.수원시_평일_일별_혼잡시간강도_LV6.csv
# input/17.수원시_인구정보(고령)_격자.geojson
# input/18.수원시_인구정보(생산가능)_격자.geojson
# input/19.수원시_인구정보(유소년)_격자.geojson
# input/20.수원시_교통노드.geojson
# input/21.수원시_교통링크.geojson
# input/22.수원시_상세도로망_LV6.geojson
# input/26.수원시_인도(2017).geojson
# input/27.수원시_도로명주소(건물).geojson
# input/28.수원시_건물연면적_격자.geojson
# input/29.수원시_법정경계(시군구).geojson
# input/30.수원시_법정경계(읍면동).geojson
# input/31.수원시_행정경계(읍면동).geojson
# input/32.수원시_지적도.geojson

# %% [markdown]
# # 결측값 처리

# %% [markdown]
# ## 1. 버스정류장

# %%
버스정류장 = pd.read_csv('input/1.수원시_버스정류장.csv')
버스정류장.shape
# Out:
# (1179, 14)

# %% [markdown]
# - 쉘터, BIS설치여부, LED, LCD, LED+LCD복합형, 알뜰형, 임대형(음성)의 결측은 모두 미설치를 나타내므로 0으로 대체

# %%
fill_val = {'쉘터':0, 'BIS설치여부':0, 'LED':0, 'LCD':0, 'LED+LCD복합형':0, '알뜰형':0, '임대형(음성)':0}
버스정류장.fillna(fill_val, inplace=True)

# %%
버스정류장['환승역타입'].value_counts()
# Out:
# 일반    1167
# 환승       1
# Name: 환승역타입, dtype: int64

# %%
버스정류장.fillna({'환승역타입':'일반'}, inplace=True)

# %% [markdown]
# ## 2~6. 승하차이력

# %%
승하차이력1 = pd.read_csv('input/2.수원시_버스정류장별_승하차이력(1).csv')
승하차이력2 = pd.read_csv('input/3.수원시_버스정류장별_승하차이력(2).csv')
승하차이력3 = pd.read_csv('input/4.수원시_버스정류장별_승하차이력(3).csv')
승하차이력4 = pd.read_csv('input/5.수원시_버스정류장별_승하차이력(4).csv')
승하차이력5 = pd.read_csv('input/6.수원시_버스정류장별_승하차이력(5).csv')

print('승하차이력1 :', 승하차이력1.shape)
print('승하차이력2 :', 승하차이력2.shape)
print('승하차이력3 :', 승하차이력3.shape)
print('승하차이력4 :', 승하차이력4.shape)
print('승하차이력5 :', 승하차이력5.shape)
# Out:
# /opt/app-root/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3072: DtypeWarning: Columns (2) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# 승하차이력1 : (364448, 12)
# 승하차이력2 : (377492, 12)
# 승하차이력3 : (722117, 12)
# 승하차이력4 : (684266, 12)
# 승하차이력5 : (360284, 12)

# %% [markdown]
# - 결측치 없음

# %% [markdown]
# ## 7. 버스정류장별 노선현황

# %%
노선현황 = pd.read_csv('input/7.수원시_버스정류장별_노선현황.csv')

# %% [markdown]
# - 결측치 없음

# %% [markdown]
# ## 8~9. 지하철 이용현황

# %%
지하철역 = pd.read_csv('input/8.수원시_지하철역_위치정보.csv')
지하철이용현황 = pd.read_csv('input/9.수원시_지하철역별_이용현황(2017~2019).csv')  # 고색역, 오목천역, 광교중앙(아주대)역, 광교(경기대)역 없음

# %%
지하철이용현황['모든요일(2017)'] = 지하철이용현황['모든요일(2017)'].apply(lambda x: x.replace(',','')).astype(int)
지하철이용현황['모든요일(2018)'] = 지하철이용현황['모든요일(2018)'].apply(lambda x: x.replace(',','')).astype(int)
지하철이용현황['모든요일(2019)'] = 지하철이용현황['모든요일(2019)'].apply(lambda x: x.replace(',','')).astype(int)

# %%
지하철이용현황.rename(columns={'역명':'역사명'}, inplace=True)
지하철이용현황['역사명'] = 지하철이용현황['역사명'].apply(lambda x: x.replace('수원','수원역') if x=='수원' else x)

# %%
지하철역별_이용현황 = pd.merge(지하철역, 지하철이용현황.drop('호선명', axis=1), how='right', on='역사명')
지하철역별_이용현황.head(2)
# Out:
#      역사명  노선명         lon        lat         행정구역   월 승하차  모든요일(2017)  \
# 0  성균관대역  경부선  126.970861  37.300344  율천동(경기수원장안)  1월  승차      419507
# 1  성균관대역  경부선  126.970861  37.300344  율천동(경기수원장안)  1월  하차      403536
#
#    모든요일(2018)  모든요일(2019)
# 0      440655      462602
# 1      428397      456366

# %% [markdown]
# - 결측치 없음
# - 단, merge된 '지하철역별_이용현황' 데이터에 '지하철역'의 고색역, 오목천역, 광교중앙(아주대)역, 광교(경기대)역 없음

# %% [markdown]
# ## 10. 옥외광고물현황

# %%
옥외광고물현황 = pd.read_csv('input/10.수원시_옥외광고물현황.csv')

# %%
옥외광고물현황.isnull().sum()
# Out:
# 광고물종류     13
# 가로         0
# 세로         0
# 높이         0
# 면          0
# 도로저촉여부    95
# 도로저촉가로     0
# 도로저촉세로     0
# 업종구분      43
# lon        0
# lat        0
# dtype: int64

# %%
옥외광고물현황[(옥외광고물현황['가로']==0) & (옥외광고물현황['세로']==0) & (옥외광고물현황['높이']==0)]['광고물종류'].value_counts()
# Out:
# 가로형간판        19
# 돌출간판          6
# 가로형간판_입체형     5
# 세로형간판         2
# 옥상간판          1
# Name: 광고물종류, dtype: int64

# %%
옥외광고물현황['광고물종류'].fillna('가로형간판', inplace=True)
옥외광고물현황['광고물종류'].isnull().sum()
# Out:
# 0

# %%
옥외광고물현황['도로저촉여부'] = np.where((옥외광고물현황['도로저촉가로']==0)&(옥외광고물현황['도로저촉세로']==0), 'N', np.nan)

# %%
옥외광고물현황['업종구분'].fillna('기타', inplace=True)
옥외광고물현황['업종구분'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ## 11. 대기오염도 측정현황

# %%
대기오염도_측정현황 = pd.read_csv('input/11.수원시_대기오염도_측정현황.csv')

# %%
대기오염도_측정현황['비고'].value_counts()
# Out:
# 설치전(2019.4월 설치)    3
# Name: 비고, dtype: int64

# %%
대기오염도_측정현황.drop('비고', axis=1, inplace=True)

# %% [markdown]
# ## 12. 주차장 현황

# %%
주차장현황 = pd.read_csv('input/12.수원시_주차장현황.csv')

# %% [markdown]
# - 결측치 없음

# %% [markdown]
# ## 13. 기상데이터

# %%
기상데이터 = pd.read_csv('input/13.수원시_기상데이터(2020).csv')

# %%
기상데이터.isnull().sum()
# Out:
# 일시            0
# 기온(°C)        3
# 강수량(mm)    7819
# 풍속(m/s)       1
# 습도(%)         0
# 적설(cm)     8679
# 지면상태       8784
# dtype: int64

# %%
print(기상데이터.shape)
기상데이터.head(2)
# Out:
# (8784, 7)
#                 일시  기온(°C)  강수량(mm)  풍속(m/s)  습도(%)  적설(cm)  지면상태
# 0  2020-01-01 0:00    -6.0      NaN      1.5     64     NaN   NaN
# 1  2020-01-01 1:00    -6.3      NaN      2.4     74     NaN   NaN

# %%
# 적설, 지면상태 삭제
기상데이터.drop(['지면상태','적설(cm)'], axis=1, inplace=True)

# 강수량 결측치 보완 - https://m.blog.naver.com/PostView.nhn?blogId=waterforall&logNo=120170457602&proxyReferer=https:%2F%2Fwww.google.com%2F
# 확률강우량 산정을 위한 EDA 기법의 적용 : http://www.dbpia.co.kr.ssl.library.dongduk.ac.kr:8010/journal/articleDetail?nodeId=NODE01246273
# 결측 강우량 보정방법에 관한 연구 : https://www.kci.go.kr/kciportal/ci/sereArticleSearch/ciSereArtiView.kci?sereArticleSearchBean.artiId=ART001020782
### 결측치 어떻게 할지 상의 -- 일단 전 시간 데이터로 대체

# 전 시간 데이터로 대체
기상데이터.fillna(method='ffill', inplace=True)

# %%
기상데이터['강수량(mm)'].fillna(method='bfill', inplace=True)

# %% [markdown]
# ## 14~16. 유동인구

# %%
시간대별_유동인구 = pd.read_csv('input/14.수원시_시간대별_유동인구(2020).csv')
성연령별_유동인구 = pd.read_csv('input/15.수원시_성연령별_유동인구(2020).csv')
요일별_유동인구 = pd.read_csv('input/16.수원시_요일별_유동인구(2020).csv')

# %% [markdown]
# - 결측치 없음

# %% [markdown]
# ## 23. 추정교통량

# %%
추정교통량 = pd.read_csv('input/23.수원시_평일_일별_시간대별_추정교통량_LV6.csv')
# Out:
# /opt/app-root/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3072: DtypeWarning: Columns (7) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
추정교통량.isnull().sum()
# Out:
# 상세도로망_LinkID        0
# 도로등급                0
# 링크길이                0
# 도로명             52175
# 시도명                 0
# 시군구명                0
# 읍면동명                0
# 시간적범위               0
# 전체_추정교통량            0
# 승용차_추정교통량           0
# 버스_추정교통량            0
# 화물차_추정교통량           0
# dtype: int64

# %%
추정교통량[(추정교통량['도로명'].notnull()) & (추정교통량['도로등급']==107) & (추정교통량['읍면동명']=='평동') & (추정교통량['링크길이']==0.016)].head(2)
# Out:
#       상세도로망_LinkID  도로등급   링크길이   도로명  시도명    시군구명 읍면동명 시간적범위  전체_추정교통량  \
# 4153   47835113401   107  0.016   서부로  경기도  수원시권선구   평동     0        55
# 4301   47835338201   107  0.016  오목천로  경기도  수원시권선구   평동     0        52
#
#       승용차_추정교통량  버스_추정교통량  화물차_추정교통량
# 4153         45         0         10
# 4301         48         0          4

# %%
# 도로명 결측
# 도로등급, 읍면동명, 링크길이가 같은 결측 아닌 도로명 중 최빈값으로 대체.........하고싶은데 모르겠으니 일단 결측 행 삭제

추정교통량 = 추정교통량.dropna()
추정교통량['도로명'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ## 24~25. 혼잡강도

# %%
혼잡빈도강도 = pd.read_csv('input/24.수원시_평일_일별_혼잡빈도강도_LV6.csv')
혼잡시간강도 = pd.read_csv('input/25.수원시_평일_일별_혼잡시간강도_LV6.csv')

# %%
혼잡빈도강도.isnull().sum()
# Out:
# 상세도로망_LinkID       0
# 도로등급               0
# 링크길이               0
# 도로명             1421
# 시도명                0
# 시군구명               0
# 읍면동명               0
# 혼잡빈도강도             0
# dtype: int64

# %%
혼잡시간강도.isnull().sum()
# Out:
# 상세도로망_LinkID       0
# 도로등급               0
# 링크길이               0
# 도로명             1421
# 시도명                0
# 시군구명               0
# 읍면동명               0
# 혼잡시간강도             0
# dtype: int64

# %%
혼잡빈도강도 = 혼잡빈도강도.dropna()
혼잡시간강도 = 혼잡시간강도.dropna()
일별_혼잡강도 = pd.merge(혼잡빈도강도, 혼잡시간강도)#, on='상세도로망_LinkID'
일별_혼잡강도.head(2)
# Out:
#    상세도로망_LinkID  도로등급  링크길이       도로명  시도명   시군구명  읍면동명  혼잡빈도강도    시군구명  \
# 0   47835381601   101  3.13  수원광명고속도로  경기도  수원시권선구  금곡동   25.93  수원시권선구
# 1   47835381901   101  3.13  수원광명고속도로  경기도  수원시권선구  금곡동   27.30  수원시권선구
#
#    혼잡시간강도
# 0   31.83
# 1   33.87

# %% [markdown]
# - 결측치 없음

# %%
#!pip install jupyter_contrib_nbextensions && jupyter contrib nbextension install
# !pip install jupyter_nbextensions_configurator jupyter_contrib_nbextensions
# Out:
# Requirement already satisfied: jupyter_nbextensions_configurator in /opt/app-root/lib/python3.6/site-packages (0.4.1)
# Requirement already satisfied: jupyter_contrib_nbextensions in /opt/app-root/lib/python3.6/site-packages (0.5.1)
# Requirement already satisfied: ipython-genutils in /opt/app-root/lib/python3.6/site-packages (from jupyter_contrib_nbextensions) (0.2.0)
# Requirement already satisfied: nbconvert>=4.2 in /opt/app-root/lib/python3.6/site-packages (from jupyter_contrib_nbextensions) (5.6.1)
# Requirement already satisfied: lxml in /opt/app-root/lib/python3.6/site-packages (from jupyter_contrib_nbextensions) (4.4.1)
# Requirement already satisfied: jupyter-core in /opt/app-root/lib/python3.6/site-packages (from jupyter_contrib_nbextensions) (4.7.0)
# Requirement already satisfied: traitlets>=4.1 in /opt/app-root/lib/python3.6/site-packages (from jupyter_contrib_nbextensions) (4.3.2)
# Requirement already satisfied: jupyter-highlight-selected-word>=0.1.1 in /opt/app-root/lib/python3.6/site-packages (from jupyter_contrib_nbextensions) (0.2.0)
# Requirement already satisfied: pyyaml in /opt/app-root/lib/python3.6/site-packages (from jupyter_contrib_nbextensions) (5.3.1)
# Requirement already satisfied: notebook>=4.0 in /opt/app-root/lib/python3.6/site-packages (from jupyter_contrib_nbextensions) (6.1.6)
# Requirement already satisfied: tornado in /opt/app-root/lib/python3.6/site-packages (from jupyter_contrib_nbextensions) (6.1)
# Requirement already satisfied: jupyter-latex-envs>=1.3.8 in /opt/app-root/lib/python3.6/site-packages (from jupyter_contrib_nbextensions) (1.4.6)
# Requirement already satisfied: jupyter-contrib-core>=0.3.3 in /opt/app-root/lib/python3.6/site-packages (from jupyter_contrib_nbextensions) (0.3.3)
# Requirement already satisfied: setuptools in /opt/app-root/lib/python3.6/site-packages (from jupyter-contrib-core>=0.3.3->jupyter_contrib_nbextensions) (51.3.3)
# Requirement already satisfied: ipython in /opt/app-root/lib/python3.6/site-packages (from jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (7.16.1)
# Requirement already satisfied: jinja2>=2.4 in /opt/app-root/lib/python3.6/site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (2.11.2)
# Requirement already satisfied: entrypoints>=0.2.2 in /opt/app-root/lib/python3.6/site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (0.3)
# Requirement already satisfied: nbformat>=4.4 in /opt/app-root/lib/python3.6/site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (5.1.2)
# Requirement already satisfied: testpath in /opt/app-root/lib/python3.6/site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (0.4.4)
# Requirement already satisfied: bleach in /opt/app-root/lib/python3.6/site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (3.2.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/app-root/lib/python3.6/site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (1.4.3)
# Requirement already satisfied: defusedxml in /opt/app-root/lib/python3.6/site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (0.6.0)
# Requirement already satisfied: pygments in /opt/app-root/lib/python3.6/site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (2.7.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in /opt/app-root/lib/python3.6/site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (0.8.4)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/app-root/lib/python3.6/site-packages (from jinja2>=2.4->nbconvert>=4.2->jupyter_contrib_nbextensions) (1.1.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /opt/app-root/lib/python3.6/site-packages (from nbformat>=4.4->nbconvert>=4.2->jupyter_contrib_nbextensions) (3.2.0)
# Requirement already satisfied: importlib-metadata in /opt/app-root/lib/python3.6/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.4->nbconvert>=4.2->jupyter_contrib_nbextensions) (1.7.0)
# Requirement already satisfied: attrs>=17.4.0 in /opt/app-root/lib/python3.6/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.4->nbconvert>=4.2->jupyter_contrib_nbextensions) (20.3.0)
# Requirement already satisfied: six>=1.11.0 in /opt/app-root/lib/python3.6/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.4->nbconvert>=4.2->jupyter_contrib_nbextensions) (1.15.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /opt/app-root/lib/python3.6/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.4->nbconvert>=4.2->jupyter_contrib_nbextensions) (0.17.3)
# Requirement already satisfied: jupyter-client>=5.3.4 in /opt/app-root/lib/python3.6/site-packages (from notebook>=4.0->jupyter_contrib_nbextensions) (6.1.7)
# Requirement already satisfied: ipykernel in /opt/app-root/lib/python3.6/site-packages (from notebook>=4.0->jupyter_contrib_nbextensions) (5.4.2)
# Requirement already satisfied: terminado>=0.8.3 in /opt/app-root/lib/python3.6/site-packages (from notebook>=4.0->jupyter_contrib_nbextensions) (0.9.1)
# Requirement already satisfied: argon2-cffi in /opt/app-root/lib/python3.6/site-packages (from notebook>=4.0->jupyter_contrib_nbextensions) (20.1.0)
# Requirement already satisfied: pyzmq>=17 in /opt/app-root/lib/python3.6/site-packages (from notebook>=4.0->jupyter_contrib_nbextensions) (20.0.0)
# Requirement already satisfied: Send2Trash in /opt/app-root/lib/python3.6/site-packages (from notebook>=4.0->jupyter_contrib_nbextensions) (1.5.0)
# Requirement already satisfied: prometheus-client in /opt/app-root/lib/python3.6/site-packages (from notebook>=4.0->jupyter_contrib_nbextensions) (0.9.0)
# Requirement already satisfied: python-dateutil>=2.1 in /opt/app-root/lib/python3.6/site-packages (from jupyter-client>=5.3.4->notebook>=4.0->jupyter_contrib_nbextensions) (2.8.1)
# Requirement already satisfied: ptyprocess in /opt/app-root/lib/python3.6/site-packages (from terminado>=0.8.3->notebook>=4.0->jupyter_contrib_nbextensions) (0.6.0)
# Requirement already satisfied: decorator in /opt/app-root/lib/python3.6/site-packages (from traitlets>=4.1->jupyter_contrib_nbextensions) (4.4.2)
# Requirement already satisfied: cffi>=1.0.0 in /opt/app-root/lib/python3.6/site-packages (from argon2-cffi->notebook>=4.0->jupyter_contrib_nbextensions) (1.14.4)
# Requirement already satisfied: pycparser in /opt/app-root/lib/python3.6/site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.0->jupyter_contrib_nbextensions) (2.20)
# Requirement already satisfied: webencodings in /opt/app-root/lib/python3.6/site-packages (from bleach->nbconvert>=4.2->jupyter_contrib_nbextensions) (0.5.1)
# Requirement already satisfied: packaging in /opt/app-root/lib/python3.6/site-packages (from bleach->nbconvert>=4.2->jupyter_contrib_nbextensions) (20.8)
# Requirement already satisfied: zipp>=0.5 in /opt/app-root/lib/python3.6/site-packages (from importlib-metadata->jsonschema!=2.5.0,>=2.4->nbformat>=4.4->nbconvert>=4.2->jupyter_contrib_nbextensions) (3.1.0)
# Requirement already satisfied: jedi>=0.10 in /opt/app-root/lib/python3.6/site-packages (from ipython->jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (0.17.2)
# Requirement already satisfied: pickleshare in /opt/app-root/lib/python3.6/site-packages (from ipython->jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (0.7.5)
# Requirement already satisfied: backcall in /opt/app-root/lib/python3.6/site-packages (from ipython->jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /opt/app-root/lib/python3.6/site-packages (from ipython->jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (3.0.8)
# Requirement already satisfied: pexpect in /opt/app-root/lib/python3.6/site-packages (from ipython->jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (4.7.0)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /opt/app-root/lib/python3.6/site-packages (from jedi>=0.10->ipython->jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (0.7.1)
# Requirement already satisfied: wcwidth in /opt/app-root/lib/python3.6/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (0.2.5)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/app-root/lib/python3.6/site-packages (from packaging->bleach->nbconvert>=4.2->jupyter_contrib_nbextensions) (2.4.7)
